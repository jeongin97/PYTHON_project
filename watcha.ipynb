# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re
import pyautogui


driver = webdriver.Chrome('C:/Temp/chromedriver')
#뒤로가기 버튼 하면 홈으로 감
#뒤로가기 해서 https://watcha.com/staffmades/409 해당 주소로 이동하도록 해야함
driver.get('https://watcha.com/staffmades/409')

position = pyautogui.position()
print(pyautogui.size())
while True:
    print("현재 위치 :" , pyautogui.position())
    time.sleep(5)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re
import pyautogui


driver = webdriver.Chrome('C:/Temp/chromedriver')
#뒤로가기 버튼 하면 홈으로 감
#페이지가 다시 https://watcha.com/staffmades/409 해당 주소로 이동하도록 해야함
driver.get('https://watcha.com/staffmades/409')

position = pyautogui.position()
#print(pyautogui.size())
#while True:
#    print("현재 위치 :" , pyautogui.position())
#    time.sleep(5)

#마우스 첫번째 
pyautogui.moveTo(200, 450)

#클릭
pyautogui.click(clicks= 2, interval=2)

#다시 홈화면
driver.get('https://watcha.com/staffmades/409')

#마우스 x축 이동
pyautogui.moveTo(350, 450, duration=1)
pyautogui.click(clicks= 2, interval=2)
driver.get('https://watcha.com/staffmades/409')

pyautogui.moveTo(650, 450, duration=1)
pyautogui.click(clicks= 2, interval=2)
driver.get('https://watcha.com/staffmades/409')

pyautogui.moveTo(700, 450, duration=1)
pyautogui.click(clicks= 2, interval=2)
driver.get('https://watcha.com/staffmades/409')

pyautogui.moveTo(900, 450, duration=1)
pyautogui.click(clicks= 2, interval=2)
driver.get('https://watcha.com/staffmades/409')


#이 다음엔 스크롤 내린 뒤 x값 초기화 해야함.
pyautogui.scroll(10)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re
import pyautogui


driver = webdriver.Chrome('C:/Temp/chromedriver')
#뒤로가기 버튼 하면 홈으로 감
#페이지가 다시 https://watcha.com/staffmades/409 해당 주소로 이동하도록 해야함
driver.get('https://watcha.com/staffmades/409')

position = pyautogui.position()
#print(pyautogui.size())
#while True:
#    print("현재 위치 :" , pyautogui.position())
#    time.sleep(5)

now_height = driver.execute_script('return document.body.scrollHeight;')
print(now_height)

while True:
    #컨텐츠 첫번째 
    pyautogui.moveTo(155, 450 , duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    print(now_height)

    #컨텐츠 두번째
    pyautogui.moveTo(400, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')

    #컨텐츠 세번쨰
    pyautogui.moveTo(650, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')

    #컨텐츠 네번째
    pyautogui.moveTo(700, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')

    #컨텐츠 다섯번째
    pyautogui.moveTo(900, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    
    i=1
    while True:
        pyautogui.scroll(-188)
        time.sleep(2)
        pyautogui.moveTo(200, 450)
        i=i+1
        if i==2:
            break
# Out:
# 960
# 960
# 960
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4388/3835807919.py in <module>
#      30     pyautogui.moveTo(400, 450, duration=1)
#      31     pyautogui.click(clicks= 2, interval=2)
# ---> 32     driver.get('https://watcha.com/staffmades/409')
#      33
#      34     #컨텐츠 세번쨰
#
# ~\anaconda3\envs\pydatavenv\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\envs\pydatavenv\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re
import pyautogui


driver = webdriver.Chrome('C:/Temp/chromedriver')
#뒤로가기 버튼 하면 홈으로 감
#페이지가 다시 https://watcha.com/staffmades/409 해당 주소로 이동하도록 해야함
driver.get('https://watcha.com/staffmades/409')

readLinks=driver.find_elements_by_css_selector('#root > div.css-4mzu8x-NavManager > main > div.css-4b375e > section > ul > li > div.css-pge0c7-Row > ul > li > div > div.css-cssveg > div.css-omgs1s > div.css-bh4lon')
for readLink in readLinks:
    readLink.doubleclick()
    driver.get('https://watcha.com/staffmades/409')
time.sleep(0.5)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re
import pyautogui


driver = webdriver.Chrome('C:/Temp/chromedriver')
#뒤로가기 버튼 하면 홈으로 감
#페이지가 다시 https://watcha.com/staffmades/409 해당 주소로 이동하도록 해야함
driver.get('https://watcha.com/staffmades/409')

position = pyautogui.position()
#print(pyautogui.size())
#while True:
#    print("현재 위치 :" , pyautogui.position())
#    time.sleep(5)

#끝까지 내리기
#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")


now_height = driver.execute_script('return document.body.scrollHeight;')
#print(now_height)

current_scroll_height=0
while True:
    
    print(currnet_scroll_height)
    
    #컨텐츠 첫번째 
    pyautogui.moveTo(155, 450 , duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(currnet_scroll_height)

    #컨텐츠 두번째
    pyautogui.moveTo(400, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(currnet_scroll_height)

    #컨텐츠 세번쨰
    pyautogui.moveTo(650, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(currnet_scroll_height)

    #컨텐츠 네번째
    pyautogui.moveTo(700, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(currnet_scroll_height)

    #컨텐츠 다섯번째
    pyautogui.moveTo(900, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(currnet_scroll_height)
    
    i=1
    while True:
        current_scroll_height=current_scroll_height-188
        pyautogui.scroll(current_scroll_height)
        time.sleep(2)
        pyautogui.moveTo(155, 450)
        i=i+1
        if i==2:
            break
    
    if (current_scroll_height * -1)%564==0:
        break

while True:
    #컨텐츠 첫번째
    pyautogui.scroll(current_scroll_height)
    pyautogui.moveTo(155, 450 , duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    
    while True:
        current_scroll_height=current_scroll_height-188
        pyautogui.scroll(current_scroll_height)
        time.sleep(2)
        pyautogui.moveTo(155, 450)
        i=i+1
        if i==2:
            break

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re
import pyautogui


driver = webdriver.Chrome('C:/Temp/chromedriver')
#뒤로가기 버튼 하면 홈으로 감
#페이지가 다시 https://watcha.com/staffmades/409 해당 주소로 이동하도록 해야함
driver.get('https://watcha.com/staffmades/409')

position = pyautogui.position()
#print(pyautogui.size())
#while True:
#    print("현재 위치 :" , pyautogui.position())
#    time.sleep(5)

#끝까지 내리기
#driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")


#now_height = driver.execute_script('return document.body.scrollHeight;')
#print(now_height)

current_scroll_height=0
while True:
    
    pyautogui.scroll(currnet_scroll_height)
    #컨텐츠 첫번째 
    pyautogui.moveTo(155, 450 , duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    #pyautogui.scroll(currnet_scroll_height)

    #컨텐츠 두번째
    pyautogui.moveTo(400, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(currnet_scroll_height)

    #컨텐츠 세번쨰
    pyautogui.moveTo(650, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(currnet_scroll_height)

    #컨텐츠 네번째
    pyautogui.moveTo(700, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(currnet_scroll_height)

    #컨텐츠 다섯번째
    pyautogui.moveTo(900, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(currnet_scroll_height)
    
    i=1
    while True:
        current_scroll_height=current_scroll_height-188
        pyautogui.scroll(current_scroll_height)
        time.sleep(2)
        #pyautogui.moveTo(155, 450)
        i=i+1
        if i==2:
            break

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re
import pyautogui


driver = webdriver.Chrome('C:/Temp/chromedriver')
#뒤로가기 버튼 하면 홈으로 감
#페이지가 다시 https://watcha.com/staffmades/409 해당 주소로 이동하도록 해야함
driver.get('https://watcha.com/staffmades/409')

position = pyautogui.position()
#print(pyautogui.size())
#while True:
#    print("현재 위치 :" , pyautogui.position())
#    time.sleep(5)

now_height = driver.execute_script('return document.body.scrollHeight;')
#print(now_height)

current_scroll_height=0
while True:
    

    #컨텐츠 첫번째 
    pyautogui.moveTo(155, 450 , duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)

    #컨텐츠 두번째
    pyautogui.moveTo(400, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)

    #컨텐츠 세번쨰
    pyautogui.moveTo(650, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)

    #컨텐츠 네번째
    pyautogui.moveTo(700, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)
    
    #컨텐츠 다섯번째
    pyautogui.moveTo(900, 450, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)
    
    i=1
    
    #스크롤내림
    while True:
        current_scroll_height=current_scroll_height-188
        pyautogui.scroll(current_scroll_height)
        time.sleep(2)
        pyautogui.moveTo(155, 450)
        i=i+1
        if i==2:
            break
    if (current_scroll_height * -1)%564==0:
        break
        
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
pyautogui.scroll(-188)

        
while True:
    

    #컨텐츠 첫번째 
    pyautogui.moveTo(155, 450 , duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)
    
    
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    pyautogui.scroll(-188)


    #컨텐츠 두번째

    pyautogui.moveTo(400, 550, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)
    
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    pyautogui.scroll(-188)

    #컨텐츠 세번쨰

    pyautogui.moveTo(650, 550, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)

    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    pyautogui.scroll(-188)

    #컨텐츠 네번째

    pyautogui.moveTo(700, 550, duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)
    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    pyautogui.scroll(-188)
    
    #컨텐츠 다섯번째

    pyautogui.moveTo(900, 550 ,duration=1)
    pyautogui.click(clicks= 2, interval=2)
    driver.get('https://watcha.com/staffmades/409')
    pyautogui.scroll(current_scroll_height)

    driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
    pyautogui.scroll(-188)    
    
    i=1
    while True:
        current_scroll_height=current_scroll_height-188
        pyautogui.scroll(current_scroll_height)
        time.sleep(2)
        pyautogui.moveTo(155, 450)
        i=i+1
        if i==2:
            break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11544/2554760824.py in <module>
#      37
#      38     #컨텐츠 세번쨰
# ---> 39     pyautogui.moveTo(650, 450, duration=1)
#      40     pyautogui.click(clicks= 2, interval=2)
#      41     driver.get('https://watcha.com/staffmades/409')
#
# ~\anaconda3\envs\pydatavenv\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     596     def wrapper(*args, **kwargs):
#     597         failSafeCheck()
# --> 598         returnVal = wrappedFunction(*args, **kwargs)
#     599         _handlePause(kwargs.get("_pause", True))
#     600         return returnVal
#
# ~\anaconda3\envs\pydatavenv\lib\site-packages\pyautogui\__init__.py in moveTo(x, y, duration, tween, logScreenshot, _pause)
#    1281
#    1282     _logScreenshot(logScreenshot, "moveTo", "%s,%s" % (x, y), folder=".")
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
import time
import re
import pyautogui


driver = webdriver.Chrome('C:/Temp/chromedriver')
#뒤로가기 버튼 하면 홈으로 감
#페이지가 다시 https://watcha.com/staffmades/409 해당 주소로 이동하도록 해야함
driver.get('https://watcha.com/staffmades/409')


driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')




#driver.execute_script('return document.body.scrollHeight;')
# Out:
# 0
# 1
# 2
# 3
# 4
