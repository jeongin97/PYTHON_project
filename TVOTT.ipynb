# %%
import pandas as pd
from konlpy.tag import Okt
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import wordcloud
import re
import seaborn as sns

font_path = "data/THEdog.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

df=pd.read_csv('./output/project/퍼센트/통합장르백분률.csv')
df1=pd.read_csv('./output/project/퍼센트/통합세부장르백분률.csv')

# %%
df=df.set_index(keys="index")

# %%
df
# Out:
#             cnt  percent
# index
# 액션       5230.0    10.46
# 모혐        200.0     0.40
# 애니메이션    5061.0    10.12
# 코미디      3117.0     6.23
# 범죄       3705.0     7.41
# 드라마      7192.0    14.38
# 공포       2000.0     4.00
# 스릴러      2233.0     4.47
# 미스테리     1200.0     2.40
# 퀴즈쇼       200.0     0.40
# 리얼리티     3380.0     6.76
# 로맨스      3694.0     7.39
# 토크쇼      1050.0     2.10
# 예능        968.0     1.94
# 모험        632.0     1.26
# 판타지      1162.0     2.32
# 틴에이저      233.0     0.47
# TV드라마     133.0     0.27
# 로맨틱코미디    803.0     1.61
# 미스터리      563.0     1.13
# 음악        760.0     1.52
# 스포츠       780.0     1.56
# 시대극       100.0     0.20
# 시트콤        66.0     0.13
# 시사교양     1266.0     2.53
# 역사         66.0     0.13
# 다큐        436.0     0.87
# 전쟁        266.0     0.53
# SF       1033.0     2.07
# 에로티시즘     500.0     1.00
# 가족         90.0     0.18
# 막장        570.0     1.14
# 버라이어티 쇼   520.0     1.04
# 사극        270.0     0.54
# 서바이벌      110.0     0.22
# 여행        320.0     0.64
# 추리         90.0     0.18

# %%
del df['cnt']

# %%
df
# Out:
#          percent
# index
# 액션         10.46
# 모혐          0.40
# 애니메이션      10.12
# 코미디         6.23
# 범죄          7.41
# 드라마        14.38
# 공포          4.00
# 스릴러         4.47
# 미스테리        2.40
# 퀴즈쇼         0.40
# 리얼리티        6.76
# 로맨스         7.39
# 토크쇼         2.10
# 예능          1.94
# 모험          1.26
# 판타지         2.32
# 틴에이저        0.47
# TV드라마       0.27
# 로맨틱코미디      1.61
# 미스터리        1.13
# 음악          1.52
# 스포츠         1.56
# 시대극         0.20
# 시트콤         0.13
# 시사교양        2.53
# 역사          0.13
# 다큐          0.87
# 전쟁          0.53
# SF          2.07
# 에로티시즘       1.00
# 가족          0.18
# 막장          1.14
# 버라이어티 쇼     1.04
# 사극          0.54
# 서바이벌        0.22
# 여행          0.64
# 추리          0.18

# %%
plt.figure(figsize=(15,10))
print(plt.gcf())
s = df

plt.title("TV,OTT 통합",size=20)
plt.xlabel('퍼센티지',size=15)
plt.ylabel('장르',size=15)

ax = plt.gca() #Axes(Axis)
print(ax)
ax.tick_params(axis='x', colors='red')
ax.tick_params(axis='y', colors='red')

mycolors = sns.color_palette('Set3',len(s.index))
plt.barh(s.index,s.percent, color=mycolors)
#plt.show()
plt.savefig('./output/project/tv,ott통합(장르).png')
# Out:
# Figure(1080x720)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df1=df1.set_index(keys="index")

# %%
df1
# Out:
#             cnt  percent
# index
# 애니메이션    3675.0     9.19
# 범죄       1262.0     3.16
# 드라마      3358.0     8.40
# 스릴러      4164.0    10.41
# 코미디      1473.0     3.68
# 로맨스      5530.0    13.83
# 공포        650.0     1.63
# 좀비       1351.0     3.38
# 음식       1053.0     2.63
# 로맨틱코미디   3221.0     8.05
# 액션       1248.0     3.12
# 스포츠      1052.0     2.63
# 틴에이저      336.0     0.84
# 전쟁       1352.0     3.38
# 모험        839.0     2.10
# TV드라마     766.0     1.92
# 판타지       395.0     0.99
# 가족        382.0     0.96
# 미스터리      312.0     0.78
# SF        146.0     0.37
# 역사        146.0     0.37
# 시트콤       146.0     0.37
# 시대극       109.0     0.27
# 음악        769.0     1.92
# 예능        543.0     1.36
# 다큐        406.0     1.02
# 리얼리티     1980.0     4.95
# 막장        570.0     1.43
# 버라이어티 쇼   520.0     1.30
# 사극        270.0     0.68
# 서바이벌      110.0     0.28
# 시사교양     1200.0     3.00
# 여행        320.0     0.80
# 추리         90.0     0.23
# 토크쇼       250.0     0.63

# %%
del df1['cnt']

# %%
df1
# Out:
#          percent
# index
# 애니메이션       9.19
# 범죄          3.16
# 드라마         8.40
# 스릴러        10.41
# 코미디         3.68
# 로맨스        13.83
# 공포          1.63
# 좀비          3.38
# 음식          2.63
# 로맨틱코미디      8.05
# 액션          3.12
# 스포츠         2.63
# 틴에이저        0.84
# 전쟁          3.38
# 모험          2.10
# TV드라마       1.92
# 판타지         0.99
# 가족          0.96
# 미스터리        0.78
# SF          0.37
# 역사          0.37
# 시트콤         0.37
# 시대극         0.27
# 음악          1.92
# 예능          1.36
# 다큐          1.02
# 리얼리티        4.95
# 막장          1.43
# 버라이어티 쇼     1.30
# 사극          0.68
# 서바이벌        0.28
# 시사교양        3.00
# 여행          0.80
# 추리          0.23
# 토크쇼         0.63

# %%
plt.figure(figsize=(15,10))
print(plt.gcf())
s = df1

plt.title("TV,OTT 통합",size=20)
plt.xlabel('퍼센티지',size=15)
plt.ylabel('세부장르',size=15)

ax = plt.gca() #Axes(Axis)
print(ax)
ax.tick_params(axis='x', colors='red')
ax.tick_params(axis='y', colors='red')

mycolors = sns.color_palette('Set3',len(s.index))
plt.barh(s.index,s.percent, color=mycolors)
#plt.show()
plt.savefig('./output/project/세부장르png')
# Out:
# Figure(1080x720)
# AxesSubplot(0.125,0.125;0.775x0.755)
