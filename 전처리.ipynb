# %%
import pandas as pd
import re

yesterday = pd.read_csv('./output/넷플릭스_어제.csv')
yesterdayGR = pd.read_csv('./output/넷플릭스_어제_장르.csv',error_bad_lines=False)

#display(yesterday)
#display(yesterdayGR)

thismonth=pd.read_csv('./output/넷플릭스_탑10(이번 달).csv')
display(thismonth)

thismonthMovieGR = pd.read_csv('./output/넷플릭스_영화_장르(이번 달).csv',error_bad_lines=False)
display(thismonthMovieGR)

thismonthTvGR = pd.read_csv('./output/넷플릭스_티비쇼_장르(이번 달).csv',error_bad_lines=False)
display(thismonthTvGR)

thismonth1=pd.concat([thismonth,thismonthMovieGR,thismonthTvGR] , axis=1)
display(thismonth1)

thismonth1.to_csv('./output/project/넷플릭스_이번 달_.csv')
# Out:
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                         이번달 영화 top10  \
# 0  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...
# 1                                         The Guilty
# 2                         Asura: The City of Madness
# 3                                           Blackhat
# 4                                           Security
# 5                                             Flight
# 6                              No One Gets Out Alive
# 7                        Kingdom: Ashin of the North
# 8                                        The Snowman
# 9                                              After
#
#                 이번 달 티비쇼 top10
# 0         Hometown Cha-Cha-Cha
# 1                   Squid Game
# ...

# %%
yesterday = pd.read_csv('./output/넷플릭스_어제.csv')
yesterdayGR = pd.read_csv('./output/넷플릭스_어제_장르.csv',error_bad_lines=False)

display(yesterday)
display(yesterdayGR)

yesterday1=pd.concat([yesterday,yesterdayGR] , axis=1)
display(yesterday1)

yesterday1.to_csv('./output/project/넷플릭스_어제_.csv')
# Out:
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                          전체 순위                      키즈 순위  \
# 0         Hometown Cha-Cha-Cha  Octonauts: Above & Beyond
# 1                      My Name        A Tale Dark & Grimm
# 2                   Squid Game      SpongeBob SquarePants
# 3            Reflection of You           Bread Barbershop
# 4         The King's Affection            A Haunted House
# 5  The Way of the Househusband    Let's Go! GALAXY GUARDS
# 6   The Fisherman and the City           Pokémon Journeys
# 7                Paik's Spirit              Spirited Away
# 8            Hospital Playlist               Corpse Bride
# 9                         D.P.                   Doraemon
#
#                                                영화 순위  \
# ...

# %%
#thisweek
thisweekMovieGR = pd.read_csv('./output/넷플릭스_영화_장르(이번주).csv',error_bad_lines=False)
display(thisweekMovieGR)

thisweektvGR = pd.read_csv('./output/넷플릭스_티비쇼_장르(이번주).csv',error_bad_lines=False)
display(thisweektvGR)

thisweek1=pd.concat([thisweekMovieGR,thisweektvGR] , axis=1)
display(thisweek1)

thisweek1.to_csv('./output/project/넷플릭스_이번 주_.csv')
# Out:
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   이번주 영화 탑10_장르 이번주 영화 탑10_세부장르
# 0      Animated           Anime
# 1         Crime    Disapperance
# 2        Action       Terorrism
# 3      Thriller           Spies
# 4         Crime             NaN
# 5        Comedy       Shrinking
# 6      Animated           Anime
# 7        Action           Spies
# 8      Animated             NaN
# 9        Horror         Zombies
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   이번주 티비쇼 top10_장르 이번주 티비쇼 top10_세부장르
# 0           Comedy            Rom Com
# ...

# %%
#lastweek
lastweekMovieGR = pd.read_csv('./output/넷플릭스_영화_장르(저번 주).csv',error_bad_lines=False)
display(lastweekMovieGR)

lastweektvGR = pd.read_csv('./output/넷플릭스_티비쇼_장르(저번 주).csv',error_bad_lines=False)
display(lastweektvGR)

lastweek1=pd.concat([lastweekMovieGR,lastweektvGR] , axis=1)
display(lastweek1)

lastweek1.to_csv('./output/project/넷플릭스_저분 주_.csv')
# Out:
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   저번 주 영화 탑10_장르 저번 주 영화 탑10_세부장르
# 0       Animated            Anime
# 1          Crime     Disapperance
# 2          Crime              NaN
# 3          Drama           Planes
# 4       Thriller            Spies
# 5         Horror             Trap
# 6         Horror          Zombies
# 7       Thriller              NaN
# 8         Action        Terorrism
# 9       Animated              NaN
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   저번 주 티비쇼 top10_장르 저번 주 티비쇼 top10_세부장르
# 0            Comedy             Rom Com
# ...

# %%
#lastmonth

lastmonthMovieGR = pd.read_csv('./output/넷플릭스_영화_장르(저번 달).csv',error_bad_lines=False)
display(lastmonthMovieGR)

lastmonthtvGR = pd.read_csv('./output/넷플릭스_티비쇼_장르(저번 달).csv',error_bad_lines=False)
display(lastmonthtvGR)

lastmonth1=pd.concat([lastmonthMovieGR,lastmonthtvGR] , axis=1)
display(lastmonth1)

lastmonth1.to_csv('./output/project/넷플릭스_저번 달_.csv')
# Out:
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   저번 달 영화 탑10_장르 저번 달 영화 탑10_세부장르
# 0         Action          Revenge
# 1         Action            Crime
# 2         Action              NaN
# 3         Action        Terorrism
# 4         Horror          Zombies
# 5       Thriller        Thrillers
# 6       Thriller       Conspiracy
# 7         Horror              NaN
# 8         Horror              NaN
# 9      Adventure    Serial killer
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   저번 달 티비쇼 top10_장르 저번 달 티비쇼 top10_세부장르
# 0            Comedy             Rom Com
# ...

# %%
thisweektop = pd.read_csv('./output/넷플릭스_탑10(이번주).csv',error_bad_lines=False)
thismonthtop = pd.read_csv('./output/넷플릭스_탑10(이번 달).csv',error_bad_lines=False)
lastweektop = pd.read_csv('./output/넷플릭스_탑10(저번 주).csv',error_bad_lines=False)
lastmonthtop = pd.read_csv('./output/넷플릭스_탑10(저번 달).csv',error_bad_lines=False)


netflix_final=pd.concat([thisweektop,thisweek1,thismonthtop,thismonth1,lastweektop,lastweek1,lastmonthtop,lastmonth1], axis=1)
display(netflix_final)


netflix_final.to_csv('./output/project/넷플릭스_종합(어제 제외)_.csv')
# Out:
# C:\Users\na\anaconda3\envs\pydatavenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                         이번주 영화 top10  \
# 0  Demon Slayer -Kimetsu no Yaiba- The Movie: Mug...
# 1                                         The Guilty
# 2                                           Security
# 3                                           Blackhat
# 4                         Asura: The City of Madness
# 5                                         Downsizing
# 6                       Violet Evergarden: The Movie
# 7                                   Mr. & Mrs. Smith
# 8                                        The Snowman
# 9                        Kingdom: Ashin of the North
#
#                  이번주 티비쇼 top10 이번주 영화 탑10_장르 이번주 영화 탑10_세부장르 이번주 티비쇼 top10_장르  \
# ...
